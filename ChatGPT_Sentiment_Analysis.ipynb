# %%
import pandas as pd

file_path = 'chatgpt_reviews.csv' 

df = pd.read_csv(file_path, nrows=5000, low_memory=False)

df = df[['content', 'score']].dropna()

print("✅ Finally! Data is loaded and Pandas is working.")
display(df.head())
# Out:
# ✅ Finally! Data is loaded and Pandas is working.
#                                              content  score
# 0  Gpt 4 version was best. updated version is not...      1
# 1                                               ❤️❤️      5
# 2                                                نور      5
# 3                sooooooooo gooooooooooooooooooooood      5
# 4  I’ve been using this app consistently for the ...      5

# %%
from textblob import TextBlob

def get_sentiment(text):
    analysis = TextBlob(str(text))
    # Polarity check: >0 positive, <0 negative, else neutral
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    elif analysis.sentiment.polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

df['Sentiment'] = df['content'].apply(get_sentiment)

print("✅ Sentiment Analysis Complete!")

display(df[['content', 'Sentiment']].head())
# Out:
# ✅ Sentiment Analysis Complete!
#                                              content Sentiment
# 0  Gpt 4 version was best. updated version is not...  Positive
# 1                                               ❤️❤️   Neutral
# 2                                                نور   Neutral
# 3                sooooooooo gooooooooooooooooooooood   Neutral
# 4  I’ve been using this app consistently for the ...  Positive

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))


sns.countplot(data=df, x='Sentiment', palette='magma')


plt.title('ChatGPT User Reviews: Sentiment Distribution', fontsize=16)
plt.xlabel('Sentiment Type', fontsize=12)
plt.ylabel('Number of Reviews', fontsize=12)

plt.show()
# Out:
# C:\Users\acer1\AppData\Local\Temp\ipykernel_100\4244702523.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Sentiment', palette='magma')
